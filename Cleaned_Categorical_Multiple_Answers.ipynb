# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\Nawaf AlHermesi\OneDrive\Desktop\Capstone Project\Multiple Categorical Answers Questions.xlsx",header=1)

# %%
df
# Out:
#        Individaul ID             Evening meal/Dinner  \
# 0                  1        Everyday (7 days a week)
# 1                  2        Everyday (7 days a week)
# 2                  3        Everyday (7 days a week)
# 3                  4        Everyday (7 days a week)
# 4                  5        Everyday (7 days a week)
# ...              ...                             ...
# 21949          22109  Most days (4 to 6 days a week)
# 21950          22110        Everyday (7 days a week)
# 21951          22111        Everyday (7 days a week)
# 21952          22112        Everyday (7 days a week)
# 21953          22113        Everyday (7 days a week)
#
#                                 Lunch  \
# 0      Most days (4 to 6 days a week)
# 1      Some days (1 to 3 days a week)
# 2            Everyday (7 days a week)
# 3            Everyday (7 days a week)
# 4            Everyday (7 days a week)
# ...                               ...
# 21949        Everyday (7 days a week)
# ...

# %%
df.columns = df.columns.str.replace("\t", "", regex=False)

# %%
df = df.fillna("Unknown")

# %%
df
# Out:
#        Individaul ID             Evening meal/Dinner  \
# 0                  1        Everyday (7 days a week)
# 1                  2        Everyday (7 days a week)
# 2                  3        Everyday (7 days a week)
# 3                  4        Everyday (7 days a week)
# 4                  5        Everyday (7 days a week)
# ...              ...                             ...
# 21949          22109  Most days (4 to 6 days a week)
# 21950          22110        Everyday (7 days a week)
# 21951          22111        Everyday (7 days a week)
# 21952          22112        Everyday (7 days a week)
# 21953          22113        Everyday (7 days a week)
#
#                                 Lunch  \
# 0      Most days (4 to 6 days a week)
# 1      Some days (1 to 3 days a week)
# 2            Everyday (7 days a week)
# 3            Everyday (7 days a week)
# 4            Everyday (7 days a week)
# ...                               ...
# 21949        Everyday (7 days a week)
# ...

# %%
df.head(1)
# Out:
#    Individaul ID       Evening meal/Dinner                           Lunch  \
# 0              1  Everyday (7 days a week)  Most days (4 to 6 days a week)
#
#   Outside of school/college - playing out/recreational  \
# 0                                       60-1 minutes
#
#   At school/college but not in lesson times  (e.g. break/lunch times/after school)  \
# 0                                       60-1 minutes
#
#   Outside of school/college - organised sports/dance  (e.g. football, rugby, cricket, dance, Zumba, gymnastics, cycling, martial arts)  \
# 0                                   0 minutes (None)
#
#   In school/college lessons  (e.g. PE lessons) Sad or upset     Lonely  \
# 0                                 60-1 minutes    Some days  Some days
#
#   Confident  ... Bullying Pupils/students with radical or extremist views  \
# 0    Rarely  ...     Good      This is not an issue at our school/college
#
#   Behaviour  \
# 0        Ok
#
# ...

# %%
df.columns = (
    df.columns
    .str.strip()
    .str.replace(r"\s*\(.*?\)", "", regex=True)      # remove parentheses
    .str.replace("â€™", "’", regex=False)            # fix apostrophes
    .str.replace("â€¦", "…", regex=False)            # fix ellipses
    .str.replace("Â", "", regex=False)               # fix weird padding
    .str.replace(" +", " ", regex=True)              # remove double spaces
)

# %%
option_columns = [col for col in df.columns if col not in ["Individual ID"]]

for col in option_columns:
    print(col)
# Out:
# Individaul ID
# Evening meal/Dinner
# Lunch
# Outside of school/college - playing out/recreational
# At school/college but not in lesson times
# Outside of school/college - organised sports/dance
# In school/college lessons
# Sad or upset
# Lonely
# Confident
# Stressed or anxious
# Happy
# Bad tempered or angry
# Stressed or anxious.1
# Sad or upset.1
# Lonely.1
# Bad tempered or angry.1
# I feel like I belong to my school/college community
# My school/college helps me if I am worried or have a problem
# I enjoy going to school/college
# My school/college is a welcoming and caring place
# There are good things to do before and after school/college
# There are good things to do at break times/lunch times
# I get on well with staff in my school/college
# School/college toilets
# Travelling to and from school/college
# During lessons at school/college
# At school/college, not in lessons
# Alcohol
# Drugs
# Litter and recycling
# How to manage money
# Self-harm
# Smoking
# ...

# %%
question_map =  { 
    #q1
    "Evening meal/Dinner": "In a normal week, how often do you have the following (this means not just a snack or a drink)?",
    "Lunch": "In a normal week, how often do you have the following (this means not just a snack or a drink)?",
    
    #q2
    "Outside of school/college - playing out/recreational" : "How many minutes a week are you physically active for?  ",
    "At school/college but not in lesson times" : "How many minutes a week are you physically active for?  ",
    "Outside of school/college - organised sports/dance": "How many minutes a week are you physically active for?  ",
    "In school/college lessons": "How many minutes a week are you physically active for?  ",
    
    #q3
    "Sad or upset" : "How often do you feel the following?",
    "Lonely" : "How often do you feel the following?",
    "Confident" : "How often do you feel the following?",
    "Stressed or anxious" : "How often do you feel the following?",
    "Happy" : "How often do you feel the following?",
    "Bad tempered or angry": "How often do you feel the following?",

    #q4
    "Stressed or anxious.1" : "How well do you think you cope with feeling the following?",
    "Sad or upset.1" : "How well do you think you cope with feeling the following?",
    "Lonely.1" : "How well do you think you cope with feeling the following?",
    "Bad tempered or angry.1" : "How well do you think you cope with feeling the following?",

    #q5
    "I feel like I belong to my school/college community" : "How much do you agree or disagree with the following statements? ",
    "My school/college helps me if I am worried or have a problem" : "How much do you agree or disagree with the following statements? ",
    "I enjoy going to school/college" : "How much do you agree or disagree with the following statements? ",
    "My school/college is a welcoming and caring place" : "How much do you agree or disagree with the following statements? ",
    "There are good things to do before and after school/college" : "How much do you agree or disagree with the following statements? ",
    "There are good things to do at break times/lunch times" : "How much do you agree or disagree with the following statements? ",
    "I get on well with staff in my school/college" : "How much do you agree or disagree with the following statements? ",

    #q6
    "School/college toilets" : "How safe do you feel in the following places? ",
    "Travelling to and from school/college" : "How safe do you feel in the following places? ",
    "During lessons at school/college" : "How safe do you feel in the following places? ",
    "At school/college, not in lessons" : "How safe do you feel in the following places? ",

    #q7
    "Alcohol" : "How much useful information and learning have you had to help you understand the following things? (e.g. through lessons at school/college) ",
    "Drugs" : "How much useful information and learning have you had to help you understand the following things? (e.g. through lessons at school/college) ",
    "Litter and recycling" : "How much useful information and learning have you had to help you understand the following things? (e.g. through lessons at school/college) ",
    "How to manage money" : "How much useful information and learning have you had to help you understand the following things? (e.g. through lessons at school/college) ",
    "Self-harm" : "How much useful information and learning have you had to help you understand the following things? (e.g. through lessons at school/college) ",
    "Smoking" : "How much useful information and learning have you had to help you understand the following things? (e.g. through lessons at school/college) ",
    "Social, Emotional & Mental Health" : "How much useful information and learning have you had to help you understand the following things? (e.g. through lessons at school/college) ",
    "Gambling" : "How much useful information and learning have you had to help you understand the following things? (e.g. through lessons at school/college) ",
    "Bullying and ways to stop it happening in school" : "How much useful information and learning have you had to help you understand the following things? (e.g. through lessons at school/college) ",
    "The importance of cooking healthy meals" : "How much useful information and learning have you had to help you understand the following things? (e.g. through lessons at school/college) ",
    "The importance of being physically active" : "How much useful information and learning have you had to help you understand the following things? (e.g. through lessons at school/college) ",
    "The importance of eating healthily" : "How much useful information and learning have you had to help you understand the following things? (e.g. through lessons at school/college) ",
    "Being a safe driver/passenger" : "How much useful information and learning have you had to help you understand the following things? (e.g. through lessons at school/college) ",
    "Knife/weapon awareness" : "How much useful information and learning have you had to help you understand the following things? (e.g. through lessons at school/college) ",
    "Leaving home/Living independently" : "How much useful information and learning have you had to help you understand the following things? (e.g. through lessons at school/college) ",
    "Gangs" : "How much useful information and learning have you had to help you understand the following things? (e.g. through lessons at school/college) ",
    "Radicalisation/extremism" : "How much useful information and learning have you had to help you understand the following things? (e.g. through lessons at school/college) ",
    "How to cope with a separation" : "How much useful information and learning have you had to help you understand the following things? (e.g. through lessons at school/college) ",
    "How to cope with a death" : "How much useful information and learning have you had to help you understand the following things? (e.g. through lessons at school/college) ",
    "Staying safe on the internet" : "How much useful information and learning have you had to help you understand the following things? (e.g. through lessons at school/college) ",
    "Pressure/encouragement to commit a crime" : "How much useful information and learning have you had to help you understand the following things? (e.g. through lessons at school/college) ",

    #q8
    "Homophobia" : "How good do you think your school/college are at dealing with the following â€¦..?",
    "Racism" : "How good do you think your school/college are at dealing with the following â€¦..?",
    "Sexism" : "How good do you think your school/college are at dealing with the following â€¦..?",
    "Smoking.1" : "How good do you think your school/college are at dealing with the following â€¦..?",
    "Alcohol.1" : "How good do you think your school/college are at dealing with the following â€¦..?",
    "Cyber-bullying" : "How good do you think your school/college are at dealing with the following â€¦..?",
    "Bullying" : "How good do you think your school/college are at dealing with the following â€¦..?",
    "Pupils/students with radical or extremist views" : "How good do you think your school/college are at dealing with the following â€¦..?",
    "Behaviour" : "How good do you think your school/college are at dealing with the following â€¦..?",
    "Drugs" : "How good do you think your school/college are at dealing with the following â€¦..?",
    "Pupils/students sharing sexual messages, pictures and videos" : "How good do you think your school/college are at dealing with the following â€¦..?",
    "People from different backgrounds not getting on well" : "How good do you think your school/college are at dealing with the following â€¦..?",
    "Gangs.1" : "How good do you think your school/college are at dealing with the following â€¦..?",
    "Pupils/students carrying knives/weapons" : "How good do you think your school/college are at dealing with the following â€¦..?",
    "Litter and recycling.1" : "How good do you think your school/college are at dealing with the following â€¦..?",
    "Unnamed: 64" : "How good do you think your school/college are at dealing with the following â€¦..?",
        }

# %%
df_long = df.melt(
    id_vars="Individaul ID",
    var_name="Option",
    value_name="Selected Option"
)

# %%
df_long["Question"] = df_long["Option"].map(question_map)

# %%
df_long["Option"] = (
    df_long["Option"]
    .str.replace("â€™", "’", regex=False)
    .str.strip()
)

# %%
df_long["Selected Option"] = (
    df_long["Selected Option"]
    .str.replace("â€™", "’", regex=False)
    .str.strip()
)

# %%
df_long = df_long[["Individaul ID", "Question", "Option", "Selected Option"]]

# %%
df_long
# Out:
#          Individaul ID                                           Question  \
# 0                    1  In a normal week, how often do you have the fo...
# 1                    2  In a normal week, how often do you have the fo...
# 2                    3  In a normal week, how often do you have the fo...
# 3                    4  In a normal week, how often do you have the fo...
# 4                    5  In a normal week, how often do you have the fo...
# ...                ...                                                ...
# 1405051          22109  How good do you think your school/college are ...
# 1405052          22110  How good do you think your school/college are ...
# 1405053          22111  How good do you think your school/college are ...
# 1405054          22112  How good do you think your school/college are ...
# 1405055          22113  How good do you think your school/college are ...
#
#                       Option           Selected Option
# ...

# %%
df_long["Question"] = (
    df_long["Question"]
    .astype(str)  # ensure string
    .str.strip()
    .str.replace(r"\s*\(.*?\)", "", regex=True)         # remove anything inside parentheses
    .str.replace("â€™", "’", regex=False)               # fix corrupted apostrophes
    .str.replace("â€¦", "…", regex=False)               # fix ellipses
    .str.replace("Â", "", regex=False)                  # remove corrupted padding
    .str.replace(" +", " ", regex=True)                 # remove multiple spaces
)

# %%
df_long = df_long[~df_long.eq("Unnamed: 64").any(axis=1)]

# %%
df_long
# Out:
#          Individaul ID                                           Question  \
# 0                    1  In a normal week, how often do you have the fo...
# 1                    2  In a normal week, how often do you have the fo...
# 2                    3  In a normal week, how often do you have the fo...
# 3                    4  In a normal week, how often do you have the fo...
# 4                    5  In a normal week, how often do you have the fo...
# ...                ...                                                ...
# 1383097          22109  How good do you think your school/college are ...
# 1383098          22110  How good do you think your school/college are ...
# 1383099          22111  How good do you think your school/college are ...
# 1383100          22112  How good do you think your school/college are ...
# 1383101          22113  How good do you think your school/college are ...
#
#                          Option                             Selected Option
# ...

# %%
df_long.to_csv(r"C:\Users\Nawaf AlHermesi\OneDrive\Desktop\Capstone Project\Cleaned\Final_Cleaned_Categorical_Multiple_Answers.csv", index=False)
